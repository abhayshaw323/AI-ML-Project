# %%
import pandas as pd
df = pd.read_csv("pulsar_data_train.csv")

# %%
sample_A = df.iloc[:1100]
sample_B = df.iloc[1100:2200]

# %%
sample_A.to_csv("sample_A_1100.csv", index=False)
sample_B.to_csv("sample_B_1100.csv", index=False)

# %%
merged_dataset.to_csv("merged_pulsar_2200.csv", index=False)

# %%
merged_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 merged_df.shape
#
# NameError: name 'merged_df' is not defined
